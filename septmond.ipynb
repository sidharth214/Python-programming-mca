# %%
#python program to convert celsius to fahrenheit
n=int(input("enter the temp :"))
f=n*(9/5)+32
print("temprature in fahrenheit :",f)
# Out:
# enter the temp :4
# temprature in fahrenheit : 39.2

# %%
#kilometer to miles 
km=int(input("Enter the distance :"))
m=km*0.62137
print("distance in miles:",round(m,2))
# Out:
# Enter the distance :4
# distance in miles: 2.49
