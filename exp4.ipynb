# %%
#dispaly first and last color
colors=input("Enter the colors seperated by commas: ")
list=colors.split(",")
print('first color:',list[0])
print('last color:',list[-1])
# Out:
# Enter the colors seperated by commas:  green,blue,black
# first color: green
# last color: black

# %%
#filename extension
filename=input("Enter the filename:")
ex=(filename.split(".")[-1])
print("extension:",ex)
# Out:
# Enter the filename: stack.c
# extension: c

# %%
#numbers seperated by commas,and also generate these list and sum
numbers=input("Enter the numbers seperated by commas:")
numbers=list(map(int,numbers.split(",")))

print("Listed numbers:",numbers)
print("Sum of numbers:",sum(numbers))
